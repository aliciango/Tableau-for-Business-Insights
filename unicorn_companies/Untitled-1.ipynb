# %%
# Loaded variable 'df' from URI: c:\Users\jingn\Documents\SQL\unicorn-companies\Cleaned_Unicorn_Companies_2022.csv
import pandas as pd
df = pd.read_csv(r'c:\Users\jingn\Documents\SQL\unicorn-companies\Cleaned_Unicorn_Companies_2022.csv')
